# %%
# import pandas as pd
# import glob
# import os

# # Option 1: Combine CSVs from a folder
# folder_path = r"C:\Users\dacdatalabs.ojt2\Desktop\workspace\DS\datasets"
# csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
# print(df.shape)

# %%
import pandas as pd
df = pd.read_csv("combined_shoppers.csv")

# %%
df.to_parquet("combined_shoppers.parquet", index=False)
